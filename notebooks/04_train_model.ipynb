# %%
# === COLAB FIX – RUN THIS FIRST ===
import os, sys
if os.path.isdir("/content/DermSavAI"):
    sys.path.append("/content/DermSavAI")
    print("Colab path fixed – src imports ready!")
# =====================================

# %%
import os
import sys

# This is the magic line that fixes everything in Colab + VS Code
sys.path.append("/content/DermSavAI")          # ← your project folder name

print("Fixed! Now src imports work")
# Out:
# Fixed! Now src imports work

# %%
from src.models.trainer import Trainer
from src.data.loader import HAM10000Dataset

print("All src imports now work perfectly!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3193572635.py in <cell line: 0>()
# ----> 1 from src.models.trainer import Trainer
#       2 from src.data.loader import HAM10000Dataset
#       3
#       4 print("All src imports now work perfectly!")
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r "/content/drive/MyDrive/DermSavAI" /content/  # ← change path if needed

import sys
sys.path.append("/content/DermSavAI")
print("Project loaded + src path fixed!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1030485510.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 get_ipython().system('cp -r "/content/drive/MyDrive/DermSavAI" /content/  # ← change path if needed')
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...
